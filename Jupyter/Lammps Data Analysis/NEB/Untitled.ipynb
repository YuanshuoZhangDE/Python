# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#数据格式化
datafile = open('log.lammps', 'r', encoding='utf-8')
datas = datafile.readlines()
#print(type(datas))
datalist = []
for i in range(len(datas)):
    datas[i] = ' '.join(datas[i].split())
    datalist.append(datas[i])

#print(datalist)
    
datafile.close()



datafile = open('log.txt', 'w')

data = '\n'.join(datalist)

datafile.write(data)

datafile.close()

# %%
contents = pd.read_csv('log.txt', sep=' ')

#star = int(input("起始行数："))

#end = int(input("结束行数："))

#contents = contents.iloc[star: end+1, :]

#contents = contents.drop(0)

contents
# Out:
#       Step  MaxReplicaForce  MaxAtomForce        GradV0        GradV1  \
# 0        0         8.036359      2.911583  5.199636e-06  4.627837e-01
# 1      100         0.141382      0.065577  2.126332e-09  1.226991e-06
# 2      200         0.128057      0.060153  5.325657e-12  2.675633e-09
# 3      300         0.107936      0.015961  1.131837e-14  5.908605e-12
# 4      400         0.108414      0.010200  8.512974e-15  3.882867e-14
# ..     ...              ...           ...           ...           ...
# 164  16400         0.012126      0.000758  5.517874e-14  1.364696e-14
# 165  16500         0.013934      0.002212  1.233315e-13  1.703950e-14
# 166  16600         0.010858      0.000388  2.231221e-14  3.290874e-15
# 167  16700         0.010402      0.000581  1.673271e-14  9.141737e-15
# 168  16765         0.009991      0.000453  4.572760e-13  2.426168e-13
#
#        GradVc       EBF       EBR       RDT  RD1  ...       RD8        PE8  \
# ...

# %%
Step = contents['RDT']

EBF = contents['EBF']

# %%
# Temp
plt.figure()

# plt.xlabel("neb time(10fs)")
plt.ylabel("EBF")
plt.plot(Step, EBF)
plt.title('neb')

plt.show()

# %% [markdown]
# #############################################################

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#数据格式化
datafile = open('log-mn.lammps', 'r', encoding='utf-8')
datas = datafile.readlines()
#print(type(datas))
datalist = []
for i in range(len(datas)):
    datas[i] = ' '.join(datas[i].split())
    datalist.append(datas[i])

#print(datalist)
    
datafile.close()



datafile = open('log-mn.txt', 'w')

data = '\n'.join(datalist)

datafile.write(data)

datafile.close()

# %%
contents = pd.read_csv('log-mn.txt', sep=' ')

contents
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-8545f83b6077> in <module>
# ----> 1 contents = pd.read_csv('log-mn.txt', sep=' ')
#       2
#       3 contents
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...

# %%
Step = contents['Step']

EBF = contents['EBF']

# %%
# Temp
plt.figure()

plt.xlabel("neb time(10fs)")
plt.ylabel("EBF")
plt.plot(Step, EBF)
plt.title('neb')

plt.show()

# %%
Step = contents['Step']

EBR = contents['EBR']

# %%
# Temp
plt.figure()

plt.xlabel("neb time(10fs)")
plt.ylabel("EBR")
plt.plot(Step, EBR)
plt.title('neb')

plt.show()
