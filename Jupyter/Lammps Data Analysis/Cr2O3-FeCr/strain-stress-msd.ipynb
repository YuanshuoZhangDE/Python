# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
t600_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/600k/stress_strain.txt"
t600_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/600k/msd.txt"

t700_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/700k/stress_strain.txt"
t700_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/700k/msd.txt"

t800_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/800k/stress_strain.txt"
t800_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/800k/msd.txt"

t900_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/900k/stress_strain.txt"
t900_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/900k/msd.txt"

t1000_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1000k/stress_strain.txt"
t1000_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1000k/msd.txt"

t1100_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1100k/stress_strain.txt"
t1100_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1100k/msd.txt"

t1200_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1200k/stress_strain.txt"
t1200_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1200k/msd.txt"

sr1_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/sr1/stress_strain.txt"
sr1_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/sr1/msd.txt"

sr1_5_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/sr1.5/stress_strain.txt"
sr1_5_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/sr1.5/msd.txt"

sr4_stress_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/sr4/stress_strain.txt"
sr4_msd_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/sr4/msd.txt"

n_sr4_stress_path = "C:/Users/Yuanshuo/Desktop/新建文件夹/s4/stress_strain.txt"

# %%
t600_Stress = pd.read_csv(t600_stress_path, sep=" ")
t600_Msd = pd.read_csv(t600_msd_path, sep=" ")

t700_Stress = pd.read_csv(t700_stress_path, sep=" ")
t700_Msd = pd.read_csv(t700_msd_path, sep=" ")

t800_Stress = pd.read_csv(t800_stress_path, sep=" ")
t800_Msd = pd.read_csv(t800_msd_path, sep=" ")

t900_Stress = pd.read_csv(t900_stress_path, sep=" ")
t900_Msd = pd.read_csv(t900_msd_path, sep=" ")

t1000_Stress = pd.read_csv(t1000_stress_path, sep=" ")
t1000_Msd = pd.read_csv(t1000_msd_path, sep=" ")

t1100_Stress = pd.read_csv(t1100_stress_path, sep=" ")
t1100_Msd = pd.read_csv(t1100_msd_path, sep=" ")

t1200_Stress = pd.read_csv(t1200_stress_path, sep=" ")
t1200_Msd = pd.read_csv(t1200_msd_path, sep=" ")

sr1_Stress = pd.read_csv(sr1_stress_path, sep=" ")
sr1_Msd = pd.read_csv(sr1_msd_path, sep=" ")

sr1_5_Stress = pd.read_csv(sr1_5_stress_path, sep=" ")
sr1_5_Msd = pd.read_csv(sr1_5_msd_path, sep=" ")

sr4_Stress = pd.read_csv(sr4_stress_path, sep=" ")
sr4_Msd = pd.read_csv(sr4_msd_path, sep=" ")

n_sr4_Stress = pd.read_csv(n_sr4_stress_path, sep=" ")

# %%
step = np.arange(1001)
strain = t600_Stress['strain']
sr1_strain = sr1_Stress['strain']
sr1_5_strain = sr1_5_Stress['strain']
sr4_strain = sr4_Stress['strain']

n_sr4_strain = n_sr4_Stress['strain']

t600_stress = t600_Stress['stress']
t700_stress = t700_Stress['stress']
t800_stress = t800_Stress['stress']
t900_stress = t900_Stress['stress']
t1000_stress = t1000_Stress['stress']
t1100_stress = t1100_Stress['stress']
t1200_stress = t1200_Stress['stress']
sr1_stress = sr1_Stress['stress']
sr1_5_stress = sr1_5_Stress['stress']
sr4_stress = sr4_Stress['stress']

n_sr4_stress = n_sr4_Stress['stress']

t600_msd_cr3 = t600_Msd['cr3']
t600_msd_o = t600_Msd['o']
t600_msd_fe = t600_Msd['fe']
t600_msd_cr = t600_Msd['cr']

t700_msd_cr3 = t700_Msd['cr3']
t700_msd_o = t700_Msd['o']
t700_msd_fe = t700_Msd['fe']
t700_msd_cr = t700_Msd['cr']

t800_msd_cr3 = t800_Msd['cr3']
t800_msd_o = t800_Msd['o']
t800_msd_fe = t800_Msd['fe']
t800_msd_cr = t800_Msd['cr']

t900_msd_cr3 = t900_Msd['cr3']
t900_msd_o = t900_Msd['o']
t900_msd_fe = t900_Msd['fe']
t900_msd_cr = t900_Msd['cr']


t1000_msd_cr3 = t1000_Msd['cr3']
t1000_msd_o = t1000_Msd['o']
t1000_msd_fe = t1000_Msd['fe']
t1000_msd_cr = t1000_Msd['cr']

t1100_msd_cr3 = t1100_Msd['cr3']
t1100_msd_o = t1100_Msd['o']
t1100_msd_fe = t1100_Msd['fe']
t1100_msd_cr = t1100_Msd['cr']

t1200_msd_cr3 = t1200_Msd['cr3']
t1200_msd_o = t1200_Msd['o']
t1200_msd_fe = t1200_Msd['fe']
t1200_msd_cr = t1200_Msd['cr']

sr1_msd_cr3 = sr1_Msd['cr3']
sr1_msd_o = sr1_Msd['o']
sr1_msd_fe = sr1_Msd['fe']
sr1_msd_cr = sr1_Msd['cr']

sr1_5_msd_cr3 = sr1_5_Msd['cr3']
sr1_5_msd_o = sr1_5_Msd['o']
sr1_5_msd_fe = sr1_5_Msd['fe']
sr1_5_msd_cr = sr1_5_Msd['cr']

sr4_msd_cr3 = sr4_Msd['cr3']
sr4_msd_o = sr4_Msd['o']
sr4_msd_fe = sr4_Msd['fe']
sr4_msd_cr = sr4_Msd['cr']

# %%
t1200_stress.max()
# Out:
# 11.121446623835899

# %%
(0.087899999999999-0.0660000000000001)/0.087899999999999
# Out:
# 0.24914675767917127

# %%
# different temp stress-strain
plt.figure()

plt.xlabel('Strain')
plt.ylabel('Stress(Gpa)')

plt.plot(strain, t600_stress, label='600k')
plt.plot(strain, t700_stress, label='700k')
plt.plot(strain, t800_stress, label='800k')
plt.plot(strain, t900_stress, label='900k')
plt.plot(strain, t1000_stress, label='1000k')
plt.plot(strain, t1100_stress, label='1100k')
plt.plot(strain, t1200_stress, label='1200k')

plt.legend(loc='upper left')
plt.title('Stress-Strain')

plt.show()

# %%
# different temp stress-strain
plt.figure()

plt.xlabel('Stress(Gpa)')
plt.ylabel('Strain')

plt.plot(t600_stress, strain, label='600k')
plt.plot(t700_stress, strain, label='700k')
plt.plot(t800_stress, strain, label='800k')
plt.plot(t900_stress, strain, label='900k')
plt.plot(t1000_stress, strain, label='1000k')
plt.plot(t1100_stress, strain, label='1100k')
plt.plot(t1200_stress, strain, label='1200k')

plt.legend(loc='upper left')
plt.title('Stress-Strain')

plt.show()

# %%
# different srate stress-strain
plt.figure()

plt.xlabel('Strain')
plt.ylabel('Stress(Gpa)')

plt.plot(sr1_strain, sr1_stress, label='$1x10^{9}s^{-1}$')
plt.plot(sr1_5_strain, sr1_5_stress, label='$1.5x10^{9}s^{-1}$')
plt.plot(strain, t1000_stress, label='$3x10^{9}s^{-1}$')
plt.plot(sr4_strain, sr4_stress, label='$4x10^{9}s^{-1}$')
plt.plot(n_sr4_strain, n_sr4_stress, label='$n4x10^{9}s^{-1}$')


plt.legend(loc='upper right')
plt.title('Stress-Strain')

plt.show()

######屈服流动#######
# ########塑性变形

# %%
# 600k msd
plt.figure()

plt.xlabel('Time(0.1ps)')
plt.ylabel('MSD')

plt.plot(step, t600_msd_cr3, label='cr3')
plt.plot(step, t600_msd_o, label='o')
plt.plot(step, t600_msd_fe, label='fe')
plt.plot(step, t600_msd_cr, label='cr')

plt.legend(loc='upper left')
plt.title('MSD 600k')

plt.show()

# %%
# 700k msd
plt.figure()

plt.xlabel('Time(0.1ps)')
plt.ylabel('MSD')

plt.plot(step, t700_msd_cr3, label='cr3')
plt.plot(step, t700_msd_o, label='o')
plt.plot(step, t700_msd_fe, label='fe')
plt.plot(step, t700_msd_cr, label='cr')

plt.legend(loc='upper left')
plt.title('MSD 700k')

plt.show()

# %%
# 1000k msd
plt.figure()

plt.xlabel('Time(0.1ps)')
plt.ylabel('MSD')

plt.plot(step, t1000_msd_cr3, label='cr3')
plt.plot(step, t1000_msd_o, label='o')
plt.plot(step, t1000_msd_fe, label='fe')
plt.plot(step, t1000_msd_cr, label='cr')

plt.legend(loc='upper left')
plt.title('MSD 1000k')

plt.show()

# %%
# Cr msd
plt.figure()

plt.xlabel('Time(0.1ps)')
plt.ylabel('MSD($10^{-20}m^{2}$)')

plt.plot(step, t600_msd_cr, label='600k')
plt.plot(step, t700_msd_cr, label='700k')
plt.plot(step, t800_msd_cr, label='800k')
plt.plot(step, t900_msd_cr, label='900k')
plt.plot(step, t1000_msd_cr, label='1000k')
plt.plot(step, t1100_msd_cr, label='1100k')
plt.plot(step, t1200_msd_cr, label='1200k')

plt.legend(loc='upper left')
plt.title('Cr MSD')

plt.show()

# %%
# Cr msd
plt.figure()

plt.xlabel('Time(0.1ps)')
plt.ylabel('MSD($10^{-20}m^{2}$)')

plt.plot(np.arange(3001), sr1_msd_cr, label='$1x10^{-9}s^{-1}$')
plt.plot(np.arange(2001), sr1_5_msd_cr, label='$1.5x10^{-9}s^{-1}$')
plt.plot(np.arange(1001), t1000_msd_cr, label='$3x10^{-9}s^{-1}$')
plt.plot(np.arange(751), sr4_msd_cr, label='$4x10^{-9}s^{-1}$')

plt.legend(loc='upper left')
plt.title('Cr MSD')

plt.show()

# %%
# Fe msd
plt.figure()

plt.xlabel('Time(0.1ps)')
plt.ylabel('MSD($10^{-20}m^{2}$)')

plt.plot(step, t600_msd_fe, label='600k')
plt.plot(step, t700_msd_fe, label='700k')
plt.plot(step, t800_msd_fe, label='800k')
plt.plot(step, t900_msd_fe, label='900k')
plt.plot(step, t1000_msd_fe, label='1000k')
plt.plot(step, t1100_msd_fe, label='1100k')
plt.plot(step, t1200_msd_fe, label='1200k')

plt.legend(loc='upper left')
plt.title('Fe MSD')

plt.show()

# %%
# Fe msd
plt.figure()

plt.xlabel('Time(0.1ps)')
plt.ylabel('MSD($10^{-20}m^{2}$)')

plt.plot(np.arange(3001), sr1_msd_fe, label='$1x10^{-9}s^{-1}$')
plt.plot(np.arange(2001), sr1_5_msd_fe, label='$1.5x10^{-9}s^{-1}$')
plt.plot(np.arange(1001), t1000_msd_fe, label='$3x10^{-9}s^{-1}$')
plt.plot(np.arange(751), sr4_msd_fe, label='$4x10^{-9}s^{-1}$')

plt.legend(loc='upper left')
plt.title('Fe MSD')

plt.show()
