# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
rdf_600k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_600k.txt"
rdf_700k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_700k.txt"
rdf_800k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_800k.txt"
rdf_900k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_900k.txt"
rdf_1000k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_1000k.txt"
rdf_1100k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_1100k.txt"
rdf_1200k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_1200k.txt"

rdf_sr1_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_sr1.txt"
rdf_sr1_5_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_sr1.5.txt"
rdf_sr4_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_sr4.txt"

rdf_3_600k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_600k.txt"
rdf_3_700k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_700k.txt"
rdf_3_800k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_800k.txt"
rdf_3_900k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_900k.txt"
rdf_3_1000k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_1000k.txt"
rdf_3_1100k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_1100k.txt"
rdf_3_1200k_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_1200k.txt"

rdf_3_sr1_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_sr1.txt"
rdf_3_sr1_5_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_sr1.5.txt"
rdf_3_sr4_path = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/rdf_3_sr4.txt"

# %%
rdf_600K = pd.read_csv(rdf_600k_path, sep=" ")
rdf_700K = pd.read_csv(rdf_700k_path, sep=" ")
rdf_800K = pd.read_csv(rdf_800k_path, sep=" ")
rdf_900K = pd.read_csv(rdf_900k_path, sep=" ")
rdf_1000K = pd.read_csv(rdf_1000k_path, sep=" ")
rdf_1100K = pd.read_csv(rdf_1100k_path, sep=" ")
rdf_1200K = pd.read_csv(rdf_1200k_path, sep=" ")

rdf_Sr1 = pd.read_csv(rdf_sr1_path, sep=" ")
rdf_Sr1_5 = pd.read_csv(rdf_sr1_5_path, sep=" ")
rdf_Sr4 = pd.read_csv(rdf_sr4_path, sep=" ")

rdf_3_600K = pd.read_csv(rdf_3_600k_path, sep=" ")
rdf_3_700K = pd.read_csv(rdf_3_700k_path, sep=" ")
rdf_3_800K = pd.read_csv(rdf_3_800k_path, sep=" ")
rdf_3_900K = pd.read_csv(rdf_3_900k_path, sep=" ")
rdf_3_1000K = pd.read_csv(rdf_3_1000k_path, sep=" ")
rdf_3_1100K = pd.read_csv(rdf_3_1100k_path, sep=" ")
rdf_3_1200K = pd.read_csv(rdf_3_1200k_path, sep=" ")

rdf_3_Sr1 = pd.read_csv(rdf_3_sr1_path, sep=" ")
rdf_3_Sr1_5 = pd.read_csv(rdf_3_sr1_5_path, sep=" ")
rdf_3_Sr4 = pd.read_csv(rdf_3_sr4_path, sep=" ")

# %%
distance_20 = rdf_600K['distance']
distance_3 = rdf_3_600K['distance']

rdf_600k = rdf_600K['g(r)']
rdf_700k = rdf_700K['g(r)']
rdf_800k = rdf_800K['g(r)']
rdf_900k = rdf_900K['g(r)']
rdf_1000k = rdf_1000K['g(r)']
rdf_1100k = rdf_1100K['g(r)']
rdf_1200k = rdf_1200K['g(r)']

rdf_sr1 = rdf_Sr1['g(r)']
rdf_sr1_5 = rdf_Sr1_5['g(r)']
rdf_sr4 = rdf_Sr4['g(r)']

rdf_3_600k = rdf_3_600K['g(r)']
rdf_3_700k = rdf_3_700K['g(r)']
rdf_3_800k = rdf_3_800K['g(r)']
rdf_3_900k = rdf_3_900K['g(r)']
rdf_3_1000k = rdf_3_1000K['g(r)']
rdf_3_1100k = rdf_3_1100K['g(r)']
rdf_3_1200k = rdf_3_1200K['g(r)']

rdf_3_sr1 = rdf_3_Sr1['g(r)']
rdf_3_sr1_5 = rdf_3_Sr1_5['g(r)']
rdf_3_sr4 = rdf_3_Sr4['g(r)']

# %%
# different temp rdf
plt.figure()

plt.xlabel('Distance')
plt.ylabel('g(r)')

plt.plot(distance_20, rdf_600k, label='600k')
plt.plot(distance_20, rdf_700k, label='700k')
plt.plot(distance_20, rdf_800k, label='800k')
plt.plot(distance_20, rdf_900k, label='900k')
plt.plot(distance_20, rdf_1000k, label='1000k')
plt.plot(distance_20, rdf_1100k, label='1100k')
plt.plot(distance_20, rdf_1200k, label='1200k')

plt.legend(loc='upper right')
plt.title('RDF')

plt.show()

# %%
# different temp rdf
plt.figure()

plt.xlabel('Distance')
plt.ylabel('g(r)')
plt.axis([1.7,1.9,2,2.4])

plt.plot(distance_3, rdf_3_600k, label='600k')
plt.plot(distance_3, rdf_3_700k, label='700k')
plt.plot(distance_3, rdf_3_800k, label='800k')
plt.plot(distance_3, rdf_3_900k, label='900k')
plt.plot(distance_3, rdf_3_1000k, label='1000k')
plt.plot(distance_3, rdf_3_1100k, label='1100k')
plt.plot(distance_3, rdf_3_1200k, label='1200k')

plt.legend(loc='upper right')
plt.title('RDF')

plt.show()

# %%
# different srate rdf
plt.figure()

plt.xlabel('Distance')
plt.ylabel('g(r)')

plt.plot(distance_20, rdf_sr1, label='$1x10^{-9}s^{-1}$')
plt.plot(distance_20, rdf_sr1_5, label='$1.5x10^{-9}s^{-1}$')
plt.plot(distance_20, rdf_1000k, label='$3x10^{-9}s^{-1}$')
plt.plot(distance_20, rdf_sr4, label='$4x10^{-9}s^{-1}$')


plt.legend(loc='upper right')
plt.title('RDF')

plt.show()

# %%
# different srate rdf
plt.figure()

plt.xlabel('Distance')
plt.ylabel('g(r)')
plt.axis([1.75,1.8,2,2.3])

plt.plot(distance_3, rdf_3_sr1, label='$1x10^{-9}s^{-1}$')
plt.plot(distance_3, rdf_3_sr1_5, label='$1.5x10^{-9}s^{-1}$')
plt.plot(distance_3, rdf_3_1000k, label='$3x10^{-9}s^{-1}$')
plt.plot(distance_3, rdf_3_sr4, label='$4x10^{-9}s^{-1}$')


plt.legend(loc='upper right')
plt.title('RDF')

plt.show()
