# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_s = pd.read_csv("state.txt", sep=" ")
data_m = pd.read_csv("material.txt", sep=" ")

# %%
Fe = data_s['Fe']

ss430_16 = data_s['ss430-16']

ss430_17 = data_s['ss430-17']

ss430_18 = data_s['ss430-18']

Crofer = data_s['Crofer']

Ebrite = data_s['Ebrite']

Min = data_m['min']

Temp300 = data_m['300K']

Temp400 = data_m['400K']

Temp500 = data_m['500K']

State = ['Initial', 'Min', '300K', '400K', '500K']

Material = ['Fe-0', 'ss430-16', 'ss430-17', 'ss430-18', 'Crofer-22.74', 'Ebrite-26.06']

# %%
fig = plt.figure(figsize=(17,16))

# Fe
fig.add_subplot(3,2,1)
#plt.xlabel("State")
plt.ylabel("Energy")
plt.plot(State, Fe)
plt.title('Fe')

# ss430_16
fig.add_subplot(3,2,2)
#plt.xlabel("State")
plt.ylabel("Energy")
plt.plot(State, ss430_16)
plt.title('ss430-16')

# ss430_17
fig.add_subplot(3,2,3)
#plt.xlabel("State")
plt.ylabel("Energy")
plt.plot(State, ss430_17)
plt.title('ss430-17')

# ss430_18
fig.add_subplot(3,2,4)
#plt.xlabel("State")
plt.ylabel("Energy")
plt.plot(State, ss430_18)
plt.title('ss430-18')

# Crofer
fig.add_subplot(3,2,5)
#plt.xlabel("State")
plt.ylabel("Energy")
plt.plot(State, Crofer)
plt.title('Crofer')

# Ebrite
fig.add_subplot(3,2,6)
#plt.xlabel("State")
plt.ylabel("Energy")
plt.plot(State, Ebrite)
plt.title('Ebrite')

plt.show()

# %%
fig = plt.figure(figsize=(17,16))

# min
fig.add_subplot(2,2,1)
#plt.xlabel("Material")
plt.ylabel("Energy")
plt.plot(Material, Min)
plt.title('min')

# 300K
fig.add_subplot(2,2,2)
#plt.xlabel("Material")
plt.ylabel("Energy")
plt.plot(Material, Temp300)
plt.title('300K')

# 400K
fig.add_subplot(2,2,3)
#plt.xlabel("Material")
plt.ylabel("Energy")
plt.plot(Material, Temp400)
plt.title('400K')

# 500K
fig.add_subplot(2,2,4)
#plt.xlabel("Material")
plt.ylabel("Energy")
plt.plot(Material, Temp500)
plt.title('500K')

plt.show()
