# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
t600_cr3 = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/600k/count_cr3.txt"
t600_fe = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/600k/count_fe.txt"
t600_o = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/600k/count_o.txt"
t600_cr = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/600k/count_cr.txt"

t700_cr3 = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/700k/count_cr3.txt"
t700_fe = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/700k/count_fe.txt"
t700_o = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/700k/count_o.txt"
t700_cr = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/700k/count_cr.txt"

t800_cr3 = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/800k/count_cr3.txt"
t800_fe = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/800k/count_fe.txt"
t800_o = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/800k/count_o.txt"
t800_cr = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/800k/count_cr.txt"

t900_cr3 = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/900k/count_cr3.txt"
t900_fe = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/900k/count_fe.txt"
t900_o = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/900k/count_o.txt"
t900_cr = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/900k/count_cr.txt"

t1000_cr3 = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1000k/count_cr3.txt"
t1000_fe = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1000k/count_fe.txt"
t1000_o = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1000k/count_o.txt"
t1000_cr = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1000k/count_cr.txt"

t1100_cr3 = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1100k/count_cr3.txt"
t1100_fe = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1100k/count_fe.txt"
t1100_o = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1100k/count_o.txt"
t1100_cr = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1100k/count_cr.txt"

t1200_cr3 = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1200k/count_cr3.txt"
t1200_fe = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1200k/count_fe.txt"
t1200_o = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1200k/count_o.txt"
t1200_cr = "C:/Users/Yuanshuo/Desktop/Repositories/Lammps/Cr2O3-FeCr/15w/stress-strain/1200k/count_cr.txt"

# %%
t600_cr3_Count = pd.read_csv(t600_cr3, sep=" ")
t600_fe_Count = pd.read_csv(t600_fe, sep=" ")
t600_o_Count = pd.read_csv(t600_o, sep=" ")
t600_cr_Count = pd.read_csv(t600_cr, sep=" ")

t700_cr3_Count = pd.read_csv(t700_cr3, sep=" ")
t700_fe_Count = pd.read_csv(t700_fe, sep=" ")
t700_o_Count = pd.read_csv(t700_o, sep=" ")
t700_cr_Count = pd.read_csv(t700_cr, sep=" ")

t800_cr3_Count = pd.read_csv(t800_cr3, sep=" ")
t800_fe_Count = pd.read_csv(t800_fe, sep=" ")
t800_o_Count = pd.read_csv(t800_o, sep=" ")
t800_cr_Count = pd.read_csv(t800_cr, sep=" ")

t900_cr3_Count = pd.read_csv(t900_cr3, sep=" ")
t900_fe_Count = pd.read_csv(t900_fe, sep=" ")
t900_o_Count = pd.read_csv(t900_o, sep=" ")
t900_cr_Count = pd.read_csv(t900_cr, sep=" ")

t1000_cr3_Count = pd.read_csv(t1000_cr3, sep=" ")
t1000_fe_Count = pd.read_csv(t1000_fe, sep=" ")
t1000_o_Count = pd.read_csv(t1000_o, sep=" ")
t1000_cr_Count = pd.read_csv(t1000_cr, sep=" ")

t1100_cr3_Count = pd.read_csv(t1100_cr3, sep=" ")
t1100_fe_Count = pd.read_csv(t1100_fe, sep=" ")
t1100_o_Count = pd.read_csv(t1100_o, sep=" ")
t1100_cr_Count = pd.read_csv(t1100_cr, sep=" ")

t1200_cr3_Count = pd.read_csv(t1200_cr3, sep=" ")
t1200_fe_Count = pd.read_csv(t1200_fe, sep=" ")
t1200_o_Count = pd.read_csv(t1200_o, sep=" ")
t1200_cr_Count = pd.read_csv(t1200_cr, sep=" ")

# %%
position_600 = t600_cr3_Count['Position.Z']
count_600_cr3 = t600_cr3_Count['Count']
count_600_fe = t600_fe_Count['Count']
count_600_o = t600_o_Count['Count']
count_600_cr = t600_cr_Count['Count']

position_700 = t700_cr3_Count['Position.Z']
count_700_cr3 = t700_cr3_Count['Count']
count_700_fe = t700_fe_Count['Count']
count_700_o = t700_o_Count['Count']
count_700_cr = t700_cr_Count['Count']

position_800 = t800_cr3_Count['Position.Z']
count_800_cr3 = t800_cr3_Count['Count']
count_800_fe = t800_fe_Count['Count']
count_800_o = t800_o_Count['Count']
count_800_cr = t800_cr_Count['Count']

position_900 = t900_cr3_Count['Position.Z']
count_900_cr3 = t900_cr3_Count['Count']
count_900_fe = t900_fe_Count['Count']
count_900_o = t900_o_Count['Count']
count_900_cr = t900_cr_Count['Count']

position_1000 = t1000_cr3_Count['Position.Z']
count_1000_cr3 = t1000_cr3_Count['Count']
count_1000_fe = t1000_fe_Count['Count']
count_1000_o = t1000_o_Count['Count']
count_1000_cr = t1000_cr_Count['Count']

position_1100 = t1100_cr3_Count['Position.Z']
count_1100_cr3 = t1100_cr3_Count['Count']
count_1100_fe = t1100_fe_Count['Count']
count_1100_o = t1100_o_Count['Count']
count_1100_cr = t1100_cr_Count['Count']

position_1200 = t1200_cr3_Count['Position.Z']
count_1200_cr3 = t1200_cr3_Count['Count']
count_1200_fe = t1200_fe_Count['Count']
count_1200_o = t1200_o_Count['Count']
count_1200_cr = t1200_cr_Count['Count']

# %%
# 600k Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_600, count_600_cr3, label='cr3')
plt.plot(position_600, count_600_o, label='o')
plt.plot(position_600, count_600_fe, label='fe')
plt.plot(position_600, count_600_cr, label='cr')

plt.legend(loc='upper right')
plt.title('600k Count Position.Z')

plt.show()

# %%
# 700k Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_700, count_700_cr3, label='cr3')
plt.plot(position_700, count_700_o, label='o')
plt.plot(position_700, count_700_fe, label='fe')
plt.plot(position_700, count_700_cr, label='cr')

plt.legend(loc='upper right')
plt.title('700k Count Position.Z')

plt.show()

# %%
# 800k Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_800, count_800_cr3, label='cr3')
plt.plot(position_800, count_800_o, label='o')
plt.plot(position_800, count_800_fe, label='fe')
plt.plot(position_800, count_800_cr, label='cr')

plt.legend(loc='upper right')
plt.title('800k Count Position.Z')

plt.show()

# %%
# 900k Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_900, count_900_cr3, label='cr3')
plt.plot(position_900, count_900_o, label='o')
plt.plot(position_900, count_900_fe, label='fe')
plt.plot(position_900, count_900_cr, label='cr')

plt.legend(loc='upper right')
plt.title('900k Count Position.Z')

plt.show()

# %%
# 1000k Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_1000, count_1000_cr3, label='cr3')
plt.plot(position_1000, count_1000_o, label='o')
plt.plot(position_1000, count_1000_fe, label='fe')
plt.plot(position_1000, count_1000_cr, label='cr')

plt.legend(loc='upper right')
plt.title('1000k Count Position.Z')

plt.show()

# %%
# 1100k Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_1100, count_1100_cr3, label='cr3')
plt.plot(position_1100, count_1100_o, label='o')
plt.plot(position_1100, count_1100_fe, label='fe')
plt.plot(position_1100, count_1100_cr, label='cr')

plt.legend(loc='upper right')
plt.title('1100k Count Position.Z')

plt.show()

# %%
# 1200k Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_1200, count_1200_cr3, label='cr3')
plt.plot(position_1200, count_1200_o, label='o')
plt.plot(position_1200, count_1200_fe, label='fe')
plt.plot(position_1200, count_1200_cr, label='cr')

plt.legend(loc='upper right')
plt.title('1200k Count Position.Z')

plt.show()

# %%
# Count - Position.Z
plt.figure()

plt.xlabel('Position Z')
plt.ylabel('Count')

plt.axvline(164, linestyle='--')
plt.plot(position_600, count_600_cr3)
plt.plot(position_700, count_700_cr3)
plt.plot(position_800, count_800_cr3)
plt.plot(position_900, count_900_cr3)
plt.plot(position_1000, count_1000_cr3)
plt.plot(position_1100, count_1100_cr3)
plt.plot(position_1200, count_1200_cr3)

plt.plot(position_600, count_600_cr)
plt.plot(position_700, count_700_cr)
plt.plot(position_800, count_800_cr)
plt.plot(position_900, count_900_cr)
plt.plot(position_1000, count_1000_cr)
plt.plot(position_1100, count_1100_cr)
plt.plot(position_1200, count_1200_cr)

plt.plot(position_600, count_600_fe)
plt.plot(position_700, count_700_fe)
plt.plot(position_800, count_800_fe)
plt.plot(position_900, count_900_fe)
plt.plot(position_1000, count_1000_fe)
plt.plot(position_1100, count_1100_fe)
plt.plot(position_1200, count_1200_fe)

plt.plot(position_600, count_600_o)
plt.plot(position_700, count_700_o)
plt.plot(position_800, count_800_o)
plt.plot(position_900, count_900_o)
plt.plot(position_1000, count_1000_o)
plt.plot(position_1100, count_1100_o)
plt.plot(position_1200, count_1200_o)

#plt.legend(loc='upper right')
plt.title('Count Position.Z')

plt.show()
