# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#数据格式化
datafile = open('log.lammps', 'r', encoding='utf-8')
datas = datafile.readlines()
#print(type(datas))
datalist = []
for i in range(len(datas)):
    datas[i] = ' '.join(datas[i].split())
    datalist.append(datas[i])

#print(datalist)
    
datafile.close()



datafile = open('log.txt', 'w')

data = '\n'.join(datalist)

datafile.write(data)

datafile.close()

# %%
contents = pd.read_csv('log.txt', sep=' ')

#star = int(input("起始行数："))

#end = int(input("结束行数："))

contents = contents.iloc[star: end+1, :]

#contents = contents.drop(0)

contents.head()
# Out:
#    Step  MaxReplicaForce  MaxAtomForce     GradV0       GradV1       GradVc  \
# 0     0      1409.522800    966.544210   3.473206  1409.522800  1409.522800
# 1   100        12.031134      6.967242  12.031134    11.407369    10.108133
# 2   200        10.348921      6.150089  10.348921     8.030229     6.527525
# 3   300        10.111017      6.119638  10.111017     6.433112     6.085274
# 4   400         9.307821      5.583457   9.307821     5.970505     6.271268
#
#           EBF       EBR       RDT  RD1        PE1       RD2        PE2  \
# 0  223.507040  0.000000  2.545370    0 -81401.570  0.333333 -81389.712
# 1    4.757870  5.245675  4.878006    0 -81404.138  0.214997 -81402.723
# 2    3.241183  5.894507  5.914887    0 -81409.002  0.250475 -81408.164
# 3    7.515685  6.702699  6.577657    0 -81415.974  0.300824 -81411.967
# 4    5.563413  6.188861  6.166862    0 -81420.054  0.337008 -81416.125
#
#         RD3        PE3  RD4        PE4
# 0  0.666667 -81245.365    1 -81178.063
# 1  0.548797 -81399.380    1 -81404.626
# 2  0.571820 -81405.761    1 -81411.655
# 3  0.619255 -81408.459    1 -81415.161
# 4  0.658531 -81414.490    1 -81420.679

# %%
Step = contents['Step']

EBF = contents['EBF']

# %%
# Temp
plt.figure()

plt.xlabel("neb time(10fs)")
plt.ylabel("EBF")
plt.plot(Step, EBF)
plt.title('neb')

plt.show()

# %% [markdown]
# #############################################################

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#数据格式化
datafile = open('C:\\Users\\Yuanshuo\\Desktop\\group-neb-all\\log.lammps', 'r', encoding='utf-8')
datas = datafile.readlines()
#print(type(datas))
datalist = []
for i in range(len(datas)):
    datas[i] = ' '.join(datas[i].split())
    datalist.append(datas[i])

#print(datalist)
    
datafile.close()



datafile = open('C:\\Users\\Yuanshuo\\Desktop\\group-neb-all\\log.txt', 'w')

data = '\n'.join(datalist)

datafile.write(data)

datafile.close()

# %%
contents = pd.read_csv('C:\\Users\\Yuanshuo\\Desktop\\group-neb-all\\log.txt', sep=' ')

star = int(input("起始行数："))

end = int(input("结束行数："))

contents = contents.iloc[star: end+1, :]

#contents = contents.drop(0)

contents.head()
# Out:
# 起始行数：20
# 结束行数：77
#      Step  MaxReplicaForce  MaxAtomForce     GradV0     GradV1     GradVc  \
# 20  20000        16.191952      6.193615  16.191952   9.938114  16.191952
# 21  21000        16.191228      6.193478  16.191228   9.952260  16.191228
# 22  22000        16.190893      6.193423  16.190893  10.067552  16.190893
# 23  23000        16.190355      6.193421  16.190355   9.927618  16.190355
# 24  24000        16.191205      6.193387  16.191205  10.033851  16.191205
#
#     EBF        EBR        RDT  RD1        PE1       RD2        PE2       RD3  \
# 20  0.0  203.97204  81.154188    0 -81362.045  0.333165 -81556.604  0.666884
# 21  0.0  203.97188  81.183336    0 -81362.045  0.333320 -81558.454  0.666667
# 22  0.0  203.96722  81.500590    0 -81362.045  0.333242 -81558.496  0.666629
# 23  0.0  203.97258  81.749795    0 -81362.045  0.333351 -81560.478  0.666769
# 24  0.0  203.96830  82.163692    0 -81362.045  0.332907 -81561.719  0.666509
#
#           PE3  RD4        PE4
# 20 -81532.800    1 -81566.017
# 21 -81533.320    1 -81566.017
# 22 -81535.880    1 -81566.012
# 23 -81538.402    1 -81566.017
# 24 -81541.346    1 -81566.013

# %%
Step = contents['Step']

EBF = contents['EBF']

# %%
# Temp
plt.figure()

plt.xlabel("neb time(10fs)")
plt.ylabel("EBF")
plt.plot(Step, EBF)
plt.title('neb')

plt.show()

# %%
Step = contents['Step']

EBR = contents['EBR']

# %%
# Temp
plt.figure()

plt.xlabel("neb time(10fs)")
plt.ylabel("EBR")
plt.plot(Step, EBR)
plt.title('neb')

plt.show()
